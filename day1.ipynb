# %%
print("Manisha")
# Out:
# Manisha

# %%
print("AI & ML")
# Out:
# AI & ML

# %%
print("Samskruti")
# Out:
# Samskruti

# %%
print("Iam starting python today")
print("3 september,2026")
print("My aim is to learn AI & ML")
# Out:
# Iam starting python today
# 3 september,2026
# My aim is to learn AI & ML

# %%
print("****************")
print("PYTHON JOURNEY")
print("****************")
print("Name: Manisha")
print("Day: 1")
print("Date: 3 september, 2026")
print("Goal: AI & ML")
print("*****************")
# Out:
# ****************
# PYTHON JOURNEY
# ****************
# Name: Manisha
# Day: 1
# Date: 3 september, 2026
# Goal: AI & ML
# *****************
