# %% [markdown]
# #Printing strings

# %%
name = "Manisha"

print(name)
print("My name is",name)
# Out:
# Manisha
# My name is Manisha

# %% [markdown]
# #Joining Strings

# %%
first_name = "Manisha"
last_name = "M"

full_name = first_name + " " + last_name

print(full_name)
# Out:
# Manisha M

# %% [markdown]
# #String Len

# %%
name = "Manisha"
print(len(name))
# Out:
# 7

# %%
text = "Hello World"
print(len(text))
# Out:
# 11

# %%
name = input("Enter your name: ")

print("Hello",name)
print("your name has",len(name ),"chracters")
# Out:
# Hello Manisha
# your name has 7 chracters

# %% [markdown]
# #DAY-8 CHALLENGE

# %%
print("===============")
print("STUDENT INTRODUCTION")
print("===============")
first_name = "Manisha"
last_name = "M"
full_name = first_name + " " + last_name
branch = input("Enter your branch: ")
college = input("Enter your college: ")

print("Full name:",full_name)
print("Branch:",branch)
print("College:",college)
print("Name Length:",len(name))

print("===================")
# Out:
# ===============
# STUDENT INTRODUCTION
# ===============
# Full name: Manisha M
# Branch: AI&ML
# College: SAMSKRUTI
# 7
# ===================
