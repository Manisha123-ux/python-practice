# %%
name = input("Enter your name: ")
print(name)
# Out:
# manisha

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")

print("My name is",name)
print("My age is",age)
# Out:
# My name is
# My age is manisha 19

# %%
age = input("Enter your age: ")
print(age)
# Out:
# 19

# %%
name = input("Enter your name: ")
print("Hello",name)
# Out:
# Hello manisha

# %%
age = input("Enter your age: ")
print("your age is",age)
# Out:
# your age is 19

# %%
age = int(input("Enter your age: "))
print(age)
# Out:
# 19

# %%
age = int(input("Enter your age: "))
print("Next year your age will be",age + 1)
# Out:
# Next year your age will be 20

# %%
print("====================")
print("STUDENT PROFILE")
print("=====================")
name = input("Enter your name: ")
age = input("Enter your age: ")
branch = input("Enter your branch: ")
city = input("Enter your city: ")

print("my name is",name)
print("my age is",age)
print("my branch is",branch)
print("I live in",city)
print("====================")
# Out:
# ====================
# STUDENT PROFILE
# =====================
# my name is manisha
# my age is 19
# my branch is AI&ML
# I live in GHATKESAR
# ====================

# %% [markdown]
# DAY5 TYPE CASTING

# %%
age = "19"
age = int(age)

print(age)
print(type(age))
# Out:
# 19
# <class 'int'>

# %%
cgpa = "7.33"
cgpa = float(cgpa)

print(cgpa)
print(type(cgpa))
# Out:
# 7.33
# <class 'float'>

# %%
age = 19
age = str(age)

print(age)
print(type(age))
# Out:
# 19
# <class 'str'>

# %%
print("====== STUDENT DETAILS ======")
name = input("Enter your name: ")
age = int(input("Enter your age: "))
cgpa = float(input("Enter your cgpa: "))
print("My name is",name)
print("My age is",age)
print("My cgpa is",cgpa)
age = int(input("Enter your age: "))
print("Next year my age will be",age + 1)
print("=============================")
# Out:
# ====== STUDENT DETAILS ======
# My name is manisha
# My age is 19
# My cgpa is 7.33
# Next year my age will be 20
# =============================
